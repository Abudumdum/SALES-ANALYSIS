# %%
import pandas as pd 
import os
import glob

# %%
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['Sales_April_2019.csv',
#  'Sales_August_2019.csv',
#  'Sales_December_2019.csv',
#  'Sales_February_2019.csv',
#  'Sales_January_2019.csv',
#  'Sales_July_2019.csv',
#  'Sales_June_2019.csv',
#  'Sales_March_2019.csv',
#  'Sales_May_2019.csv',
#  'Sales_November_2019.csv',
#  'Sales_October_2019.csv',
#  'Sales_September_2019.csv']

# %%
dataframe1 = pd.concat([pd.read_csv(f) for f in  csv_files], ignore_index = True)
dataframe1.to_csv('dataframe_new1.csv', index = False)
dataframe1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
dataframe_new1 = pd.read_csv('dataframe_new1.csv')
dataframe_new1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
dataframe_new1.sort_values(by='Order Date', ascending = True)
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 73891    147268          Wired Headphones                1      11.99
# 74701    148041      USB-C Charging Cable                1      11.95
# 76054    149343  Apple Airpods Headphones                1        150
# 76708    149964    AAA Batteries (4-pack)                1       2.99
# 76061    149350      USB-C Charging Cable                2      11.95
# ...         ...                       ...              ...        ...
# 185176      NaN                       NaN              NaN        NaN
# 185438      NaN                       NaN              NaN        NaN
# 186042      NaN                       NaN              NaN        NaN
# 186548      NaN                       NaN              NaN        NaN
# 186826      NaN                       NaN              NaN        NaN
#
#             Order Date                        Purchase Address
# 73891   01/01/19 03:07      9 Lake St, New York City, NY 10001
# ...

# %%
dataframe_new1['Month'] = dataframe_new1['Order Date'].str[0:2]
dataframe_new1 = dataframe_new1.dropna(how = 'all')
#dataframe_new1.isna()

# %%
dataframe_new1 = dataframe_new1.sort_values(by='Order Date', ascending = True)

# %%
dataframe_new1 = dataframe_new1[dataframe_new1['Month'].str[0:2] != 'Or']
dataframe_new1
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 73891   147268          Wired Headphones                1      11.99
# 74701   148041      USB-C Charging Cable                1      11.95
# 76054   149343  Apple Airpods Headphones                1        150
# 76708   149964    AAA Batteries (4-pack)                1       2.99
# 76061   149350      USB-C Charging Cable                2      11.95
# ...        ...                       ...              ...        ...
# 33264   298406    AAA Batteries (4-pack)                2       2.99
# 32308   297481     AA Batteries (4-pack)                1       3.84
# 52781   317048    AAA Batteries (4-pack)                2       2.99
# 45172   309773    AAA Batteries (4-pack)                1       2.99
# 32511   297674    AAA Batteries (4-pack)                1       2.99
#
#            Order Date                        Purchase Address Month
# 73891  01/01/19 03:07      9 Lake St, New York City, NY 10001    01
# ...

# %%
dataframe_new1['Month'].astype('int32')
dataframe_new1.head(4)
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 73891   147268          Wired Headphones                1      11.99
# 74701   148041      USB-C Charging Cable                1      11.95
# 76054   149343  Apple Airpods Headphones                1        150
# 76708   149964    AAA Batteries (4-pack)                1       2.99
#
#            Order Date                        Purchase Address Month
# 73891  01/01/19 03:07      9 Lake St, New York City, NY 10001    01
# 74701  01/01/19 03:40  760 Church St, San Francisco, CA 94016    01
# 76054  01/01/19 04:56     735 5th St, New York City, NY 10001    01
# 76708  01/01/19 05:53         75 Jackson St, Dallas, TX 75001    01

# %%
dataframe_new1['Quantity Ordered']= pd.to_numeric(dataframe_new1['Quantity Ordered'])
dataframe_new1['Price Each']= pd.to_numeric(dataframe_new1['Price Each'])

dataframe_new1['Sales'] = dataframe_new1['Quantity Ordered'] * dataframe_new1['Price Each']
dataframe_new1
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 73891   147268          Wired Headphones                 1       11.99
# 74701   148041      USB-C Charging Cable                 1       11.95
# 76054   149343  Apple Airpods Headphones                 1      150.00
# 76708   149964    AAA Batteries (4-pack)                 1        2.99
# 76061   149350      USB-C Charging Cable                 2       11.95
# ...        ...                       ...               ...         ...
# 33264   298406    AAA Batteries (4-pack)                 2        2.99
# 32308   297481     AA Batteries (4-pack)                 1        3.84
# 52781   317048    AAA Batteries (4-pack)                 2        2.99
# 45172   309773    AAA Batteries (4-pack)                 1        2.99
# 32511   297674    AAA Batteries (4-pack)                 1        2.99
#
#            Order Date                        Purchase Address Month   Sales
# ...

# %%
 results = dataframe_new1.groupby('Month').sum()
results
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 01                10903  1811768.38  1822256.73
# 02                13449  2188884.72  2202022.42
# 03                17005  2791207.83  2807100.38
# 04                20558  3367671.02  3390670.24
# 05                18667  3135125.13  3152606.75
# 06                15253  2562025.61  2577802.26
# 07                16072  2632539.56  2647775.76
# 08                13448  2230345.42  2244467.88
# 09                13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
import matplotlib.pyplot as plt 
months = range(1,13)
plt.bar(months, results['Sales'])

plt.xticks(months)
plt.ylabel='sales in USD'
plt.xlabel = 'Month number'
plt.show()

# %% [markdown]
# #### What city had the highest number of sales

# %%
 dataframe_new1['City'] =  dataframe_new1['Purchase Address'].str[-8:-6]

# %%
dataframe_new1.head(3)
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 73891   147268          Wired Headphones                 1       11.99
# 74701   148041      USB-C Charging Cable                 1       11.95
# 76054   149343  Apple Airpods Headphones                 1      150.00
#
#            Order Date                        Purchase Address Month   Sales  \
# 73891  01/01/19 03:07      9 Lake St, New York City, NY 10001    01   11.99
# 74701  01/01/19 03:40  760 Church St, San Francisco, CA 94016    01   11.95
# 76054  01/01/19 04:56     735 5th St, New York City, NY 10001    01  150.00
#
#       City
# 73891   NY
# 74701   CA
# 76054   NY

# %%
highest_city = dataframe_new1.groupby('City')['Sales'].count()
highest_city
# Out:
# City
# CA    74337
# GA    14881
# MA    19934
# ME     2455
# NY    24876
# OR    10010
# TX    24725
# WA    14732
# Name: Sales, dtype: int64

# %%
 #dataframe_new1['City Name'] =  dataframe_new1['Purchase Address'].apply(lambda x: x.split(',')[1])
#dataframe_new1.rename(columns = {'City' : 'State', 'City Name' :'City'}, inplace = True) 
#dataframe_new1.drop(columns = ['State'], inplace = True)
dataframe_new1['State'] = dataframe_new1['Purchase Address'].str[-8:-6]
dataframe_new1

# %%
highest_city_sales = dataframe_new1.groupby('City').sum() 
highest_city_sales
#dataframe_new1
# Out:
#                 Quantity Ordered  Price Each       Sales
# City
#  Atlanta                   16602  2779908.20  2795498.58
#  Austin                    11153  1809873.61  1819581.75
#  Boston                    22528  3637409.77  3661642.01
#  Dallas                    16730  2752627.82  2767975.40
#  Los Angeles               33289  5421435.23  5452570.80
#  New York City             27932  4635370.83  4664317.43
#  Portland                  14053  2307747.47  2320490.61
#  San Francisco             50239  8211461.74  8262203.91
#  Seattle                   16553  2733296.01  2747755.48

# %%
#city = dataframe_new1['City'].unique()
city =[city for city, df in dataframe_new1.groupby('City')]
plt.bar(city, highest_city_sales['Sales'])

plt.xticks(city, rotation= 'vertical', size = 8)
plt.xlabel=('City')
plt.ylabel=('sales in USD')

plt.show()

# %% [markdown]
# #### What time should advitisement be done to increase likelihood of customer purchase

# %%
dataframe_new1.head(4)
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 73891   147268          Wired Headphones                 1       11.99
# 74701   148041      USB-C Charging Cable                 1       11.95
# 76054   149343  Apple Airpods Headphones                 1      150.00
# 76708   149964    AAA Batteries (4-pack)                 1        2.99
#
#                Order Date                        Purchase Address Month  \
# 73891 2019-01-01 03:07:00      9 Lake St, New York City, NY 10001    01
# 74701 2019-01-01 03:40:00  760 Church St, San Francisco, CA 94016    01
# 76054 2019-01-01 04:56:00     735 5th St, New York City, NY 10001    01
# 76708 2019-01-01 05:53:00         75 Jackson St, Dallas, TX 75001    01
#
#         Sales            City State
# 73891   11.99   New York City    NY
# 74701   11.95   San Francisco    CA
# 76054  150.00   New York City    NY
# 76708    2.99          Dallas    TX

# %%
import datetime

# %%
dataframe_new1['Order Date'] = pd.to_datetime(dataframe_new1['Order Date'])

# %%
dataframe_new1['hour'] = dataframe_new1['Order Date'].dt.hour
dataframe_new1.rename(columns= {'hour':'Hour'}, inplace = True)
dataframe_new1.head(4)
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 73891   147268          Wired Headphones                 1       11.99
# 74701   148041      USB-C Charging Cable                 1       11.95
# 76054   149343  Apple Airpods Headphones                 1      150.00
# 76708   149964    AAA Batteries (4-pack)                 1        2.99
#
#                Order Date                        Purchase Address Month  \
# 73891 2019-01-01 03:07:00      9 Lake St, New York City, NY 10001    01
# 74701 2019-01-01 03:40:00  760 Church St, San Francisco, CA 94016    01
# 76054 2019-01-01 04:56:00     735 5th St, New York City, NY 10001    01
# 76708 2019-01-01 05:53:00         75 Jackson St, Dallas, TX 75001    01
#
#         Sales            City State  Hour  Minute
# 73891   11.99   New York City    NY     3       7
# 74701   11.95   San Francisco    CA     3      40
# 76054  150.00   New York City    NY     4      56
# ...

# %%
dataframe_new1['Minute'] = dataframe_new1['Order Date'].dt.minute
dataframe_new1.head(4)
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 73891   147268          Wired Headphones                 1       11.99
# 74701   148041      USB-C Charging Cable                 1       11.95
# 76054   149343  Apple Airpods Headphones                 1      150.00
# 76708   149964    AAA Batteries (4-pack)                 1        2.99
#
#                Order Date                        Purchase Address Month  \
# 73891 2019-01-01 03:07:00      9 Lake St, New York City, NY 10001    01
# 74701 2019-01-01 03:40:00  760 Church St, San Francisco, CA 94016    01
# 76054 2019-01-01 04:56:00     735 5th St, New York City, NY 10001    01
# 76708 2019-01-01 05:53:00         75 Jackson St, Dallas, TX 75001    01
#
#         Sales            City State  hour  Minute
# 73891   11.99   New York City    NY     3       7
# 74701   11.95   San Francisco    CA     3      40
# 76054  150.00   New York City    NY     4      56
# ...

# %%
timestamp = dataframe_new1.groupby('Hour').count()
timestamp
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hour =[hour for hour, df in dataframe_new1.groupby('Hour')]
plt.plot(hour, timestamp['Quantity Ordered'])
plt.xticks(hour)
plt.grid()
plt.xlabel('ime')
plt.ylabel('uantity ordered')
plt.show()
#its recomended to show ads at around peack purchase time which is 11am or 7pm
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 5>()
#       3 plt.xticks(hour)
#       4 plt.grid()
# ----> 5 plt.xlabel('ime')
#       6 plt.ylabel('uantity ordered')
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# #### What products are most often sold together

# %%
dataframe_new1
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 73891   147268          Wired Headphones                 1       11.99
# 74701   148041      USB-C Charging Cable                 1       11.95
# 76054   149343  Apple Airpods Headphones                 1      150.00
# 76708   149964    AAA Batteries (4-pack)                 1        2.99
# 76061   149350      USB-C Charging Cable                 2       11.95
# ...        ...                       ...               ...         ...
# 33264   298406    AAA Batteries (4-pack)                 2        2.99
# 32308   297481     AA Batteries (4-pack)                 1        3.84
# 52781   317048    AAA Batteries (4-pack)                 2        2.99
# 45172   309773    AAA Batteries (4-pack)                 1        2.99
# 32511   297674    AAA Batteries (4-pack)                 1        2.99
#
#                Order Date                        Purchase Address Month  \
# ...

# %%
duplicate = dataframe_new1[dataframe_new1['Order ID'].duplicated(keep = False)]
duplicate.head(12)
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 71311   144804          Wired Headphones                 1       11.99
# 71310   144804                    iPhone                 1      700.00
# 74737   148074      USB-C Charging Cable                 1       11.95
# 74736   148074              Google Phone                 1      600.00
# 75124   148450  Lightning Charging Cable                 1       14.95
# 75123   148450                    iPhone                 1      700.00
# 71176   144679              Google Phone                 1      600.00
# 71177   144679      USB-C Charging Cable                 1       11.95
# 74084   147451              Google Phone                 1      600.00
# 74085   147451          Wired Headphones                 1       11.99
# 70191   143738  Lightning Charging Cable                 1       14.95
# 70190   143738                    iPhone                 1      700.00
#
# ...

# %%
duplicate['Grouped']= duplicate.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
duplicate = duplicate[['Order ID', 'Grouped']].drop_duplicates()
duplicate.head()
# Out:
# C:\Users\Abdullah Oguntade\AppData\Local\Temp\ipykernel_13356\496004494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicate['Grouped']= duplicate.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
#       Order ID                            Grouped
# 71311   144804            Wired Headphones,iPhone
# 74737   148074  USB-C Charging Cable,Google Phone
# 75124   148450    Lightning Charging Cable,iPhone
# 71176   144679  Google Phone,USB-C Charging Cable
# 74084   147451      Google Phone,Wired Headphones

# %%
from itertools import combinations
from collections import Counter 
count = Counter()
for row in duplicate['Grouped']:
    row_list =row.split(',')
    count.update(Counter(combinations(row_list, 2)))

count.most_common(10)
# Out:
# [(('Lightning Charging Cable', 'iPhone'), 511),
#  (('USB-C Charging Cable', 'Google Phone'), 504),
#  (('iPhone', 'Lightning Charging Cable'), 504),
#  (('Google Phone', 'USB-C Charging Cable'), 495),
#  (('iPhone', 'Wired Headphones'), 247),
#  (('Wired Headphones', 'iPhone'), 215),
#  (('Wired Headphones', 'Google Phone'), 213),
#  (('Google Phone', 'Wired Headphones'), 210),
#  (('USB-C Charging Cable', 'Vareebadd Phone'), 190),
#  (('iPhone', 'Apple Airpods Headphones'), 187)]

# %% [markdown]
# # What product sold the most

# %%
dataframe_new1.groupby('Product')['Quantity Ordered'].sum().idxmax()
# Out:
# 'AAA Batteries (4-pack)'

# %%
product_group = dataframe_new1.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

products = [product for product, df in product_group]

plt.bar(products, quantity_ordered)
plt.ylabel=('Quantity purchased')
plt.xlabel=('Product')
plt.xticks(products, rotation ='vertical', size = 8)
plt.show()

# %%
prices = dataframe_new1.groupby('Product').mean()['Price Each']
print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
fig, ax1= plt.subplots()

ax2 =ax1.twinx()
ax1.bar(products, quantity_ordered , color ='g')
ax2.plot(products, prices, 'b-')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color ='g')
ax2.set_ylabel('price', color = 'b')
ax1.set_xticklabels(products,rotation = 'vertical', size = 8)
plt.show()
# Out:
# C:\Users\Abdullah Oguntade\AppData\Local\Temp\ipykernel_13356\582988234.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products,rotation = 'vertical', size = 8)
